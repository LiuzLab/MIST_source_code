# %%
import scanpy as sc
import anndata as ad
import pandas as pd

# %% [markdown]
# # R code to download data from R using package spatialLIBD
#
# `library("spatialLIBD")`
#
#
# `spe <- fetch_data(type = "spe") # Download the spot-level data`
#
# `write.csv(as.data.frame(spe@colData), 'Human_DLPFC_cell_meta.csv')`
#
# `writeMM(spe@assays@data$counts, 'Human_DLPFC_cell.mtx')`
#
# `gene_df <- data.frame(row.names=row.names(spe@assays@data$counts), ensID = row.names(spe@assays@data$counts))`
#
# `write.csv(gene_df, 'Human_DLPFC_gene_meta.csv')`
#
# `write.csv(spe@int_colData@listData$spatialData, 'Human_DLPFC_cell_spatialData.csv')`

# %%
gene_df = pd.read_csv("Human_DLPFC_gene_meta.csv", index_col=0)
gene_df.iloc[:3, :]
# Out:
#                            ensID
# ENSG00000243485  ENSG00000243485
# ENSG00000237613  ENSG00000237613
# ENSG00000186092  ENSG00000186092

# %%
cell_df = pd.read_csv("Human_DLPFC_cell_meta.csv", index_col=0)
cell_df.iloc[:3, :]
# Out:
#                     sample_id  Cluster  sum_umi  sum_gene subject  position  \
# AAACAACGAATAGTTC-1     151507        6      948       727  Br5292         0
# AAACAAGTATCTCCCA-1     151507        3     4261      2170  Br5292         0
# AAACAATCTACTAGCA-1     151507        2     1969      1093  Br5292         0
#
#                     replicate subject_position  discard  \
# AAACAACGAATAGTTC-1          1      Br5292_pos0    False
# AAACAAGTATCTCCCA-1          1      Br5292_pos0    False
# AAACAATCTACTAGCA-1          1      Br5292_pos0    False
#
#                                           key  ...  HVG_PCA_spatial  \
# AAACAACGAATAGTTC-1  151507_AAACAACGAATAGTTC-1  ...                5
# AAACAAGTATCTCCCA-1  151507_AAACAAGTATCTCCCA-1  ...                2
# AAACAATCTACTAGCA-1  151507_AAACAATCTACTAGCA-1  ...                3
#
#                     pseudobulk_PCA_spatial  markers_PCA_spatial  \
# AAACAACGAATAGTTC-1                       4                    3
# AAACAAGTATCTCCCA-1                       3                    1
# AAACAATCTACTAGCA-1                       5                    7
#
#                     SpatialDE_UMAP_spatial  SpatialDE_pool_UMAP_spatial  \
# AAACAACGAATAGTTC-1                       1                            1
# AAACAAGTATCTCCCA-1                       2                            2
# AAACAATCTACTAGCA-1                       2                            1
#
#                     HVG_UMAP_spatial  pseudobulk_UMAP_spatial  \
# AAACAACGAATAGTTC-1                 1                        1
# AAACAAGTATCTCCCA-1                 1                        2
# AAACAATCTACTAGCA-1                 4                        1
#
#                     markers_UMAP_spatial  spatialLIBD  ManualAnnotation
# AAACAACGAATAGTTC-1                     1           L1               NaN
# AAACAAGTATCTCCCA-1                     1           L3               NaN
# AAACAATCTACTAGCA-1                     6           L1               NaN
#
# [3 rows x 66 columns]

# %%
cell_df = cell_df[['sample_id', 'layer_guess_reordered']]
cell_df
# Out:
#                        sample_id layer_guess_reordered
# AAACAACGAATAGTTC-1        151507                Layer1
# AAACAAGTATCTCCCA-1        151507                Layer3
# AAACAATCTACTAGCA-1        151507                Layer1
# AAACACCAATAACTGC-1        151507                    WM
# AAACAGCTTTCAGAAG-1        151507                Layer6
# ...                          ...                   ...
# TTGTTGTGTGTCAAGA-1.11     151676                Layer6
# TTGTTTCACATCCAGG-1.11     151676                    WM
# TTGTTTCATTAGTCTA-1.11     151676                    WM
# TTGTTTCCATACAACT-1.11     151676                Layer6
# TTGTTTGTGTAAATTC-1.10     151676                Layer1
#
# [47681 rows x 2 columns]

# %%
cell_spatial = pd.read_csv("Human_DLPFC_cell_spatialData.csv", index_col=0)
(cell_spatial.index == cell_df.index).all()
# Out:
# True

# %%
cell_meta = pd.concat([cell_df, cell_spatial], axis=1)
cell_meta.iloc[:10,:]
# Out:
#                     sample_id layer_guess_reordered  in_tissue  array_row  \
# AAACAACGAATAGTTC-1     151507                Layer1       True          0
# AAACAAGTATCTCCCA-1     151507                Layer3       True         50
# AAACAATCTACTAGCA-1     151507                Layer1       True          3
# AAACACCAATAACTGC-1     151507                    WM       True         59
# AAACAGCTTTCAGAAG-1     151507                Layer6       True         43
# AAACAGGGTCTATATT-1     151507                Layer6       True         47
# AAACAGTGTTCCTGGG-1     151507                    WM       True         73
# AAACATTTCCCGGATT-1     151507                Layer5       True         61
# AAACCACTACACAGAT-1     151507                Layer3       True          3
# AAACCCGAACGAAATC-1     151507                Layer3       True         45
#
#                     array_col
# AAACAACGAATAGTTC-1         16
# AAACAAGTATCTCCCA-1        102
# AAACAATCTACTAGCA-1         43
# AAACACCAATAACTGC-1         19
# AAACAGCTTTCAGAAG-1          9
# AAACAGGGTCTATATT-1         13
# AAACAGTGTTCCTGGG-1         43
# AAACATTTCCCGGATT-1         97
# AAACCACTACACAGAT-1        117
# AAACCCGAACGAAATC-1        115

# %%
img_coords = pd.read_csv("Human_DLPFC_img_coords.csv", index_col=0)
(img_coords.index == cell_meta.index).all()
# Out:
# False

# %%
inds = [i.split(".")[0] for i in cell_meta.index.tolist()]
img_coords.index.tolist() == inds
# Out:
# True

# %%
cell_meta.index = inds

# %%
cell_meta = pd.concat([cell_meta, img_coords], axis=1)

# %%
data = sc.read_mtx("Human_DLPFC_cell.mtx")
data
# Out:
# AnnData object with n_obs × n_vars = 33538 × 47681

# %%
data = data.transpose()

# %%
data.obs = cell_meta
data.var = gene_df

# %%
data.obs
# Out:
#                     sample_id layer_guess_reordered  in_tissue  array_row  \
# AAACAACGAATAGTTC-1     151507                Layer1       True          0
# AAACAAGTATCTCCCA-1     151507                Layer3       True         50
# AAACAATCTACTAGCA-1     151507                Layer1       True          3
# AAACACCAATAACTGC-1     151507                    WM       True         59
# AAACAGCTTTCAGAAG-1     151507                Layer6       True         43
# ...                       ...                   ...        ...        ...
# TTGTTGTGTGTCAAGA-1     151676                Layer6       True         31
# TTGTTTCACATCCAGG-1     151676                    WM       True         58
# TTGTTTCATTAGTCTA-1     151676                    WM       True         60
# TTGTTTCCATACAACT-1     151676                Layer6       True         45
# TTGTTTGTGTAAATTC-1     151676                Layer1       True          7
#
#                     array_col  pxl_col_in_fullres  pxl_row_in_fullres
# AAACAACGAATAGTTC-1         16                2514                3276
# AAACAAGTATCTCCCA-1        102                8520                9178
# AAACAATCTACTAGCA-1         43                2878                5133
# AAACACCAATAACTGC-1         19                9581                3462
# AAACAGCTTTCAGAAG-1          9                7663                2779
# ...                       ...                 ...                 ...
# TTGTTGTGTGTCAAGA-1         77                6378                7946
# TTGTTTCACATCCAGG-1         42                9594                5512
# TTGTTTCATTAGTCTA-1         30                9827                4684
# TTGTTTCCATACAACT-1         27                8029                4491
# TTGTTTGTGTAAATTC-1         51                3489                6177
#
# [47681 rows x 7 columns]

# %%
sample_ids = list(set(data.obs['sample_id']))
sample_ids
# Out:
# [151671,
#  151676,
#  151507,
#  151508,
#  151669,
#  151509,
#  151510,
#  151670,
#  151673,
#  151674,
#  151675,
#  151672]

# %%
from tqdm.notebook import tqdm
import os

for i, sid in enumerate(tqdm(sample_ids)):
    sample_data = data[data.obs.sample_id == sid,:]
    folder = f'tissue_{sid}'
    if not os.path.exists(folder):
        os.mkdir(folder)
    sample_data.write(f"{folder}/data.h5ad")
    sample_data.obs.to_csv(f"{folder}/cell_meta.csv")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# /home/humble_local_25t/alexw/miniconda3/envs/ReST/lib/python3.9/site-packages/anndata/_core/anndata.py:1235: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
data.obs
# Out:
#                     sample_id layer_guess_reordered  in_tissue  array_row  \
# AAACAACGAATAGTTC-1     151507                Layer1       True          0
# AAACAAGTATCTCCCA-1     151507                Layer3       True         50
# AAACAATCTACTAGCA-1     151507                Layer1       True          3
# AAACACCAATAACTGC-1     151507                    WM       True         59
# AAACAGCTTTCAGAAG-1     151507                Layer6       True         43
# ...                       ...                   ...        ...        ...
# TTGTTGTGTGTCAAGA-1     151676                Layer6       True         31
# TTGTTTCACATCCAGG-1     151676                    WM       True         58
# TTGTTTCATTAGTCTA-1     151676                    WM       True         60
# TTGTTTCCATACAACT-1     151676                Layer6       True         45
# TTGTTTGTGTAAATTC-1     151676                Layer1       True          7
#
#                     array_col  pxl_col_in_fullres  pxl_row_in_fullres
# AAACAACGAATAGTTC-1         16                2514                3276
# AAACAAGTATCTCCCA-1        102                8520                9178
# AAACAATCTACTAGCA-1         43                2878                5133
# AAACACCAATAACTGC-1         19                9581                3462
# AAACAGCTTTCAGAAG-1          9                7663                2779
# ...                       ...                 ...                 ...
# TTGTTGTGTGTCAAGA-1         77                6378                7946
# TTGTTTCACATCCAGG-1         42                9594                5512
# TTGTTTCATTAGTCTA-1         30                9827                4684
# TTGTTTCCATACAACT-1         27                8029                4491
# TTGTTTGTGTAAATTC-1         51                3489                6177
#
# [47681 rows x 7 columns]
