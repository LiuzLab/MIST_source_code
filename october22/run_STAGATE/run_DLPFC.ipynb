# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
from time import sleep

# %%
from sklearn.metrics.cluster import adjusted_rand_score

# %%
import STAGATE

# %%
sids = os.listdir('/home/humble_local2_25t/alexw/MIST_round3/Human_DLPFC_ARI/')
sids = [sid for sid in sids if 'tissue_' in sid]
sids
# Out:
# ['tissue_151672',
#  'tissue_151673',
#  'tissue_151507',
#  'tissue_151510',
#  'tissue_151508',
#  'tissue_151674',
#  'tissue_151675',
#  'tissue_151669',
#  'tissue_151670',
#  'tissue_151509',
#  'tissue_151671',
#  'tissue_151676']

# %%
from tqdm.notebook import tqdm

for sample_id in tqdm(sids):
    adata = sc.read_h5ad(f"/home/humble_local2_25t/alexw/MIST_round3/Human_DLPFC_ARI/{sample_id}/data.h5ad")
    adata.var_names_make_unique()
    sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=3000)
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    adata.obsm['spatial'] = adata.obs[['array_col', 'array_row']].copy()
    STAGATE.Cal_Spatial_Net(adata, rad_cutoff=2)
    STAGATE.Stats_Spatial_Net(adata)
    adata = STAGATE.train_STAGATE(adata, alpha=0)
    STAGATE_df = pd.DataFrame(data=adata.obsm['STAGATE'], index=adata.obs_names)
    input_fn = f"STAGATE_mclust_input/{sample_id}_STAGATE_obsm.csv"
    STAGATE_df.to_csv(input_fn)
    out_fn = f"STAGATE_mclust_output/{sample_id}.csv"
    df = pd.read_csv(f"../Human_DLPFC_ARI/region_detection_results/{sample_id}/detected_regions_all_but_bayesspace.csv")
    n = len(set(df.MIST))
    cmd = f'Rscript run_mclust.R --inpath {input_fn} --outpath {out_fn} --g {n}'
    print(sample_id, n)
    os.system(cmd)
    
    res = pd.read_csv(f"STAGATE_mclust_output/{sample_id}.csv", index_col=0)

    if res.shape[0] == STAGATE_df.shape[0]:
        adata.obs['STAGATE'] = res.STAGATE
    
    adata.obs.to_csv(f"STAGATE_mclust_output/{sample_id}_obs.csv")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# ------Calculating spatial graph...
# The graph contains 31054 edges, 4015 cells.
# 7.7345 neighbors per cell on average.
# Size of Input:  (4015, 3000)
# ...
#  74%|█████████████████████████████████████████████████████████████████▍                      | 372/500 [01:30<00:30,  4.14it/s]
# ...
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 500/500 [01:42<00:00,  4.88it/s]
# tissue_151676 6
# Package 'mclust' version 5.4.9
# Type 'citation("mclust")' for citing this R package in publications.
